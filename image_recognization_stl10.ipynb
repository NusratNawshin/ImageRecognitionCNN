# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Notebook-Configuration" data-toc-modified-id="Notebook-Configuration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Notebook Configuration</a></span><ul class="toc-item"><li><span><a href="#Google-drive" data-toc-modified-id="Google-drive-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Google drive</a></span></li><li><span><a href="#Warning" data-toc-modified-id="Warning-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Warning</a></span></li><li><span><a href="#Matplotlib" data-toc-modified-id="Matplotlib-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Matplotlib</a></span></li><li><span><a href="#TensorFlow" data-toc-modified-id="TensorFlow-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>TensorFlow</a></span></li><li><span><a href="#Random-seed" data-toc-modified-id="Random-seed-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Random seed</a></span></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Loading-the-data" data-toc-modified-id="Loading-the-data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Loading the data</a></span><ul class="toc-item"><li><span><a href="#Creating-the-directory-for-the-data" data-toc-modified-id="Creating-the-directory-for-the-data-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Creating the directory for the data</a></span></li><li><span><a href="#Downloading-the-data-to-the-directory" data-toc-modified-id="Downloading-the-data-to-the-directory-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Downloading the data to the directory</a></span></li></ul></li><li><span><a href="#Getting-the-name-of-the-target" data-toc-modified-id="Getting-the-name-of-the-target-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Getting the name of the target</a></span></li><li><span><a href="#Getting-the-info" data-toc-modified-id="Getting-the-info-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Getting the info</a></span></li><li><span><a href="#Getting-the-training,-validation-and-test-data" data-toc-modified-id="Getting-the-training,-validation-and-test-data-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Getting the training, validation and test data</a></span></li><li><span><a href="#Resizing-the-data-for-pretrained-model" data-toc-modified-id="Resizing-the-data-for-pretrained-model-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Resizing the data for pretrained model</a></span></li><li><span><a href="#Preprocessing-the-data-using-pretrained-model" data-toc-modified-id="Preprocessing-the-data-using-pretrained-model-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Preprocessing the data using pretrained model</a></span></li><li><span><a href="#Shuffling,-batching-and-prefetching-the-data" data-toc-modified-id="Shuffling,-batching-and-prefetching-the-data-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Shuffling, batching and prefetching the data</a></span></li></ul></li><li><span><a href="#Training" data-toc-modified-id="Training-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Training</a></span><ul class="toc-item"><li><span><a href="#Creating-the-directory-for-the-model" data-toc-modified-id="Creating-the-directory-for-the-model-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Creating the directory for the model</a></span></li><li><span><a href="#Building-the-architecture-of-the-model" data-toc-modified-id="Building-the-architecture-of-the-model-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Building the architecture of the model</a></span></li><li><span><a href="#Freezing-the-pretrained-layers" data-toc-modified-id="Freezing-the-pretrained-layers-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Freezing the pretrained layers</a></span></li><li><span><a href="#Setting-Callbacks" data-toc-modified-id="Setting-Callbacks-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Setting Callbacks</a></span></li><li><span><a href="#Compiling-the-model" data-toc-modified-id="Compiling-the-model-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Compiling the model</a></span></li><li><span><a href="#Training-the-model" data-toc-modified-id="Training-the-model-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Training the model</a></span></li><li><span><a href="#Plotting-the-learning-curve" data-toc-modified-id="Plotting-the-learning-curve-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Plotting the learning curve</a></span><ul class="toc-item"><li><span><a href="#Creating-the-directory-for-the-figure" data-toc-modified-id="Creating-the-directory-for-the-figure-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Creating the directory for the figure</a></span></li></ul></li><li><span><a href="#Unfreezing-the-pretrained-layers" data-toc-modified-id="Unfreezing-the-pretrained-layers-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Unfreezing the pretrained layers</a></span></li><li><span><a href="#Compiling-the-model" data-toc-modified-id="Compiling-the-model-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Compiling the model</a></span></li><li><span><a href="#Training-the-model" data-toc-modified-id="Training-the-model-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Training the model</a></span></li><li><span><a href="#Plotting-the-learning-curve" data-toc-modified-id="Plotting-the-learning-curve-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Plotting the learning curve</a></span></li></ul></li><li><span><a href="#Testing" data-toc-modified-id="Testing-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Testing</a></span><ul class="toc-item"><li><span><a href="#Loading-the-saved-model" data-toc-modified-id="Loading-the-saved-model-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Loading the saved model</a></span></li><li><span><a href="#Evaluating-the-model" data-toc-modified-id="Evaluating-the-model-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Evaluating the model</a></span></li><li><span><a href="#Evaluating-the-model" data-toc-modified-id="Evaluating-the-model-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Confusion Matrix</a></span></li></ul></li><li><span><a href="#Reference" data-toc-modified-id="Reference-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Reference</a></span></li></ul></div>

# %% [markdown]
# <b>
# <p>
# <center>
# <font size='5'>
# DATS 6202 Machine Learning 1 Group 2 Project
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size='4'>
# Convolutional Neural Networks
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size='4'>
#
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size='3'>
# Data Science, Columbian College of Arts & Sciences, George Washington University
# </font>
# </center>
# </p>
#
# <p>
# <center>
# <font size='3'>
# by Nusrat Nawshin, Mahtab Barkhordarian
# </font>
# </center>
# </p>
# </b>

# %% [markdown]
# # Overview

# %% [markdown]
# - This notebook is of Machine Learning Project on Spring 2022 semester.
# - We are working on Tensorflow dataset 'stl10' [dataset link](https://www.tensorflow.org/datasets/catalog/stl10).
# - The goal of this project is to classify images using CNN.

# %% [markdown]
# # Notebook Configuration

# %% [markdown]
# ## Google drive

# %%
from google.colab import drive
import sys

# Mount Google Drive
drive.mount('/content/drive')

# Get the absolute path of the current folder
abspath_curr = '/content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/project/'

# Get the absolute path of the deep utilities folder
abspath_util_deep = '/content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/utilities/p3_deep_learning/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Warning

# %%
import warnings

# Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

# Set matplotlib sizes
plt.rc('font', size=20)
plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rc('legend', fontsize=20)
plt.rc('figure', titlesize=20)

# %% [markdown]
# ## TensorFlow

# %%
# The magic below allows us to use tensorflow version 2.x
# %tensorflow_version 2.x 
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Random seed

# %%
# The random seed
random_seed = 42

# Set random seed in tensorflow
tf.random.set_seed(random_seed)

# Set random seed in numpy
import numpy as np
np.random.seed(random_seed)

# %% [markdown]
# # Data Preprocessing

# %%
# Change working directory to the absolute path of the deep utilities folder
# %cd $abspath_util_deep

# Import the deep utitilities
# %run pmlm_utilities_deep.ipynb
# Out:
# /content/drive/My Drive/Colab Notebooks/teaching/gwu/machine_learning_I/code/utilities/p3_deep_learning

# %% [markdown]
# ## Loading the data

# %% [markdown]
# ## Creating the directory for the data

# %%
import os

# Make directory
directory = os.path.dirname(abspath_curr + '/data/')
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# ## Downloading the data to the directory

# %%
import tensorflow_datasets as tfds

# Get the name of the data
data_name = 'stl10'

# Load data
data, info = tfds.load(name=data_name,
                       data_dir=abspath_curr + '/data/',
                       as_supervised=True,
                       with_info=True)

# %% [markdown]
# ## Getting the name of the target

# %%
target = 'label'

# %% [markdown]
# ## Getting the info

# %%
# Print the splits
info.splits
# Out:
# {'test': <tfds.core.SplitInfo num_examples=8000>,
#  'train': <tfds.core.SplitInfo num_examples=5000>,
#  'unlabelled': <tfds.core.SplitInfo num_examples=100000>}

# %% [markdown]
# Our dataset has many unlabelled data but we are not using them on this project

# %%
# Get the classes
classes = info.features['label'].names

# Print the classes
classes
# Out:
# ['airplane',
#  'bird',
#  'car',
#  'cat',
#  'deer',
#  'dog',
#  'horse',
#  'monkey',
#  'ship',
#  'truck']

# %%
# Get the number of classes
n_classes = info.features['label'].num_classes

# Print the number of classes
info.features['label'].num_classes
# Out:
# 10

# %% [markdown]
# ## Getting the training, validation and test data

# %%
# Set the training, validation and test split
split_train, split_valid, split_test = 'train[:70%]', 'train[70%:]', 'test'

# Get the training data
data_train = tfds.load(name=data_name,
                       split=split_train,
                       data_dir=abspath_curr + '/data/',
                       as_supervised=True)

# Get the validation data
data_valid = tfds.load(name=data_name,
                       split=split_valid,
                       data_dir=abspath_curr + '/data/',
                       as_supervised=True)

# Get the test data
data_test = tfds.load(name=data_name,
                      split=split_test,
                      data_dir=abspath_curr + '/data/',
                      as_supervised=True)

# %%
# Total images in the trainset
len(data_train)
# Out:
# 3500

# %%
# Total images in the validation set
len(data_valid)
# Out:
# 1500

# %%
# Total images in the testset
len(data_test)
# Out:
# 8000

# %% [markdown]
# ## Image Samples
# ### Train

# %%
get_label_name = info.features['label'].int2str

im=iter(data_train)
plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  image, label = next(im)
  _ = plt.imshow(image)
  _ = plt.title(get_label_name(label))
  plt.axis("off")
plt.show()

# %% [markdown]
# ### Validation

# %%
get_label_name = info.features['label'].int2str

im=iter(data_valid)
plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  image, label = next(im)
  _ = plt.imshow(image)
  _ = plt.title(get_label_name(label))
  plt.axis("off")
plt.show()

# %% [markdown]
# ### Test

# %%
get_label_name = info.features['label'].int2str

im=iter(data_test)
plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  image, label = next(im)
  _ = plt.imshow(image)
  _ = plt.title(get_label_name(label))
  plt.axis("off")
plt.show()

# %% [markdown]
# ## Resizing the data for pretrained model

# %%
# Set the default input size for the pretrained model
global input_size
input_size = [224, 224]

# %%
# Resize the training data
data_train = data_train.map(resize)

# Resize the validation data
data_valid = data_valid.map(resize)

# Resize the test data
data_test = data_test.map(resize)

# %% [markdown]
# ## Preprocessing the data using pretrained model

# %%
# Set the preprocess_input of the pretrained model
global preprocess_input
preprocess_input = tf.keras.applications.resnet.preprocess_input

# %%
# Preprocess the training data using pretrained model
data_train = data_train.map(preprocess_pretrain)

# Preprocess the validation data using pretrained model
data_valid = data_valid.map(preprocess_pretrain)

# Preprocess the test data using pretrained model
data_test = data_test.map(preprocess_pretrain)

# %% [markdown]
# ## Shuffling, batching and prefetching the data

# %%
# Shuffling the training data
data_train = data_train.shuffle(buffer_size=1000, seed=random_seed)

# Set the batch size
batch_size = 16

# Batch and prefetch the training data
data_train = data_train.batch(batch_size).prefetch(1)

# Batch and prefetch the validation data
data_valid = data_valid.batch(batch_size).prefetch(1)

# Batch and prefetch the test data
data_test = data_test.batch(batch_size).prefetch(1)

# %% [markdown]
# # Training

# %% [markdown]
# ## Creating the directory for the model

# %%
# Make directory
directory = os.path.dirname(abspath_curr + '/result/model/')
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# ## Building the architecture of the model

# %%
# Add the pretrained layers
pretrained_model = keras.applications.ResNet50(include_top=False, weights='imagenet')

# Add GlobalAveragePooling2D layer
average_pooling = keras.layers.GlobalAveragePooling2D()(pretrained_model.output)

# Add the output layer
output = keras.layers.Dense(n_classes, activation='softmax')(average_pooling)

# Get the model
model = keras.Model(inputs=pretrained_model.input, outputs=output)

model.summary()
# Out:
# ...
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
# ...

# %% [markdown]
# ## Freezing the pretrained layers

# %%
# For each layer in the pretrained model
for layer in pretrained_model.layers:
    # Freeze the layer
    layer.trainable = False

# %% [markdown]
# ## Setting Callbacks

# %%
# ModelCheckpoint callback
model_checkpoint_cb = keras.callbacks.ModelCheckpoint(filepath=abspath_curr + '/result/model/model.h5',
                                                      save_best_only=True,
                                                      save_weights_only=True)

# EarlyStopping callback
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2,
                                                  restore_best_weights=True)

# ReduceLROnPlateau callback
reduce_lr_on_plateau_cb = keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                            patience=1)

# %% [markdown]
# ## Compiling the model
# Here we use the SGD(decay=1e-4) optimizer.

# %%
# Compile the model
model.compile(optimizer=keras.optimizers.SGD(decay=3e-4),
              loss='sparse_categorical_crossentropy',    
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
# Train, evaluate and save the best model
history = model.fit(data_train,
                    epochs=5,
                    validation_data=data_valid,
                    callbacks=[model_checkpoint_cb,
                               early_stopping_cb,
                               reduce_lr_on_plateau_cb])
# Out:
# Epoch 1/5
# 219/219 [==============================] - 58s 185ms/step - loss: 0.3833 - accuracy: 0.8957 - val_loss: 0.1675 - val_accuracy: 0.9600 - lr: 0.0100
# Epoch 2/5
# 219/219 [==============================] - 41s 173ms/step - loss: 0.1206 - accuracy: 0.9694 - val_loss: 0.1397 - val_accuracy: 0.9613 - lr: 0.0100
# Epoch 3/5
# 219/219 [==============================] - 51s 219ms/step - loss: 0.0864 - accuracy: 0.9811 - val_loss: 0.1186 - val_accuracy: 0.9673 - lr: 0.0100
# Epoch 4/5
# 219/219 [==============================] - 41s 173ms/step - loss: 0.0683 - accuracy: 0.9871 - val_loss: 0.1147 - val_accuracy: 0.9647 - lr: 0.0100
# Epoch 5/5
# 219/219 [==============================] - 41s 174ms/step - loss: 0.0579 - accuracy: 0.9900 - val_loss: 0.1044 - val_accuracy: 0.9687 - lr: 0.0100

# %% [markdown]
# ## Plotting the learning curve

# %% [markdown]
# ## Creating the directory for the figure

# %%
# Make directory
directory = os.path.dirname(abspath_curr + '/result/figure/')
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
import pandas as pd

# Create a figure
pd.DataFrame(history.history).plot(figsize=(8, 5))

# Set grid
plt.grid(True)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + '/result/figure/learning_curve_before_unfreezing.pdf')
plt.show()

# %% [markdown]
# ## Unfreezing the pretrained layers

# %%
# For each layer in the pretrained model
for layer in pretrained_model.layers:
    # Unfreeze the layer
    layer.trainable = True

# %% [markdown]
# ## Compiling the model
# Here we use a gradient descent optimizer SGD

# %%
# Compile the model
model.compile(optimizer=keras.optimizers.SGD(decay=3e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
# Train, evaluate and save the best model
history = model.fit(data_train,
                    epochs=5,
                    validation_data=data_valid,
                    callbacks=[model_checkpoint_cb,
                               early_stopping_cb,
                               reduce_lr_on_plateau_cb])
# Out:
# Epoch 1/5
# 219/219 [==============================] - 101s 417ms/step - loss: 0.1703 - accuracy: 0.9480 - val_loss: 0.1875 - val_accuracy: 0.9380 - lr: 0.0100
# Epoch 2/5
# 219/219 [==============================] - 92s 407ms/step - loss: 0.0531 - accuracy: 0.9874 - val_loss: 0.1518 - val_accuracy: 0.9520 - lr: 0.0100
# Epoch 3/5
# 219/219 [==============================] - 92s 406ms/step - loss: 0.0239 - accuracy: 0.9971 - val_loss: 0.1521 - val_accuracy: 0.9540 - lr: 0.0100
# Epoch 4/5
# 219/219 [==============================] - 94s 414ms/step - loss: 0.0162 - accuracy: 0.9986 - val_loss: 0.1028 - val_accuracy: 0.9680 - lr: 1.0000e-03
# Epoch 5/5
# 219/219 [==============================] - 94s 414ms/step - loss: 0.0125 - accuracy: 0.9986 - val_loss: 0.1010 - val_accuracy: 0.9687 - lr: 1.0000e-03

# %% [markdown]
# ## Plotting the learning curve

# %%
# Create a figure
pd.DataFrame(history.history).plot(figsize=(8, 5))

# Set grid
plt.grid(True)

# Save and show the figure
plt.tight_layout()
plt.savefig(abspath_curr + '/result/figure/learning_curve_after_unfreezing.pdf')
plt.show()

# %% [markdown]
# # Testing

# %% [markdown]
# ## Loading the saved model

# %%
# Load the saved model
model.load_weights(filepath=abspath_curr + '/result/model/model.h5')

# %% [markdown]
# ## Evaluating the model

# %%
loss, accuracy = model.evaluate(data_test)
# Out:
# 500/500 [==============================] - 58s 115ms/step - loss: 0.1035 - accuracy: 0.9671

# %% [markdown]
# ## Model Confusion Matrix

# %%
preds =  np.round(model.predict(data_test),0)
predictions = np.argmax(preds, axis=1)

# %%
test_labels = np.concatenate([y for x, y in data_test], axis=0)

# %%
predictions[:100]
# Out:
# array([2, 3, 3, 1, 9, 7, 3, 6, 6, 4, 4, 3, 5, 0, 1, 3, 6, 0, 0, 8, 7, 6,
#        9, 0, 0, 8, 5, 7, 3, 2, 2, 2, 5, 6, 6, 3, 9, 5, 1, 8, 9, 1, 6, 3,
#        1, 4, 4, 7, 2, 0, 8, 7, 0, 4, 6, 1, 6, 6, 8, 7, 7, 5, 3, 0, 9, 2,
#        9, 7, 4, 8, 1, 1, 1, 4, 5, 6, 4, 5, 0, 4, 1, 4, 0, 9, 3, 3, 9, 7,
#        3, 5, 5, 9, 7, 5, 2, 9, 6, 2, 2, 2])

# %%
test_labels[:100]
# Out:
# array([9, 3, 3, 1, 9, 7, 3, 6, 6, 4, 4, 3, 5, 0, 1, 3, 6, 0, 0, 8, 7, 6,
#        9, 0, 0, 8, 5, 7, 3, 2, 2, 2, 5, 6, 6, 3, 9, 5, 1, 8, 9, 1, 6, 3,
#        1, 4, 4, 7, 2, 0, 8, 7, 0, 4, 6, 1, 6, 6, 8, 7, 7, 5, 3, 0, 9, 2,
#        9, 7, 4, 0, 1, 1, 1, 4, 4, 6, 4, 5, 0, 4, 1, 4, 9, 9, 3, 3, 9, 7,
#        3, 5, 5, 2, 7, 5, 2, 9, 6, 2, 2, 2])

# %%
y_pred = []  # store predicted labels
y_true = []  # store true labels

# iterate over the dataset
for image_batch, label_batch in data_test:   # use dataset.unbatch() with repeat
   # append true labels
   y_true.append(label_batch)
   # compute predictions
   preds = model.predict(image_batch)
   # append predicted labels
   y_pred.append(np.argmax(preds, axis = - 1))

# convert the true and predicted labels into tensors
test_labels = tf.concat([item for item in y_true], axis = 0)
predictions = tf.concat([item for item in y_pred], axis = 0)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

names = ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']

classification_metrics = metrics.classification_report(test_labels, predictions, target_names=names)

# %%
print(classification_metrics)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.99      0.98      0.99       800
#         bird       0.98      0.97      0.98       800
#          car       0.98      0.97      0.98       800
#          cat       0.93      0.95      0.94       800
#         deer       0.98      0.95      0.96       800
#          dog       0.94      0.95      0.94       800
#        horse       0.96      0.96      0.96       800
#       monkey       0.97      0.98      0.98       800
#         ship       0.97      1.00      0.98       800
#        truck       0.97      0.97      0.97       800
#
#     accuracy                           0.97      8000
#    macro avg       0.97      0.97      0.97      8000
# weighted avg       0.97      0.97      0.97      8000

# %%
confusion_matrix = confusion_matrix(test_labels, predictions)
confusion_matrix
# Out:
# array([[786,   1,   2,   0,   0,   1,   0,   0,   8,   2],
#        [  0, 777,   0,   9,   2,   2,   2,   7,   1,   0],
#        [  2,   0, 778,   0,   0,   0,   2,   1,   0,  17],
#        [  0,   2,   0, 757,   5,  26,   0,  10,   0,   0],
#        [  0,   2,   1,  20, 760,   6,  10,   0,   1,   0],
#        [  0,   3,   0,  22,   1, 757,  15,   2,   0,   0],
#        [  0,   2,   2,   1,   8,  13, 767,   4,   1,   2],
#        [  0,   4,   0,   3,   3,   4,   0, 785,   1,   0],
#        [  1,   0,   0,   0,   0,   0,   0,   0, 797,   2],
#        [  2,   0,  11,   0,   0,   0,   1,   0,  13, 773]])

# %%
import itertools
def plot_confusion_matrix(cm, classes,
             normalize=False,
             title='Confusion matrix',
             cmap=plt.cm.Greens):
    #Add Normalization Option
    '''prints pretty confusion metric with normalization option '''
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
fig, ax = plt.subplots(figsize=(12, 12))
plot_confusion_matrix(confusion_matrix, 
                      names,
                     normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# From the confusion matrix we can observe that the model is doing very well at predicting each category as all of the accuracies are above 95%. This model is giving 100% accuracy at detecting ship and its least performace is at predicting cat, dog and deer. Probably the face of them are very similar.

# %% [markdown]
# # Reference

# %% [markdown]
# - The source codes are cloned from professor Yuxiao Huang's github repository:  [https://github.com/yuxiaohuang/teaching/tree/master/gwu/machine_learning_I/spring_2022/code]
#
# - Theoritical concepts: [https://github.com/yuxiaohuang/teaching/blob/master/gwu/machine_learning_I/spring_2022/slides/p3_deep_learning/p3_c2_supervised_learning/p3_c2_s3_convolutional_neural_networks/convolutional_neural_networks.pdf]
#
# - Image outputs: [https://tensorflow.google.cn/tutorials/load_data/images]
#
# - Confusion Matrix: [https://github.com/lydiateinfalt/DATS6202-MachineLearningI-Fall2021/blob/main/Group1_Final_Project_ResNet50_LRSchedule.ipynb]
#
# - Dataset: [https://www.tensorflow.org/datasets/catalog/stl10?msclkid=ca6b5065c3f411ec85773373f8cbf246]
